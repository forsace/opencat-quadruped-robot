# %% [markdown]
# <a href="https://colab.research.google.com/github/forsace/opencat-quadruped-robot/blob/main/notebooks/CosyVoice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 一键运行 CosyVoice
# !git clone --recursive https://github.com/KevinWang676/CosyVoice.git
# %cd CosyVoice
# !pip install -r requirements.txt
# !mkdir -p pretrained_models
# !git clone https://www.modelscope.cn/iic/CosyVoice-300M.git pretrained_models/CosyVoice-300M
# !export PYTHONPATH=third_party/Matcha-TTS
# !python3 webui_colab.py
# Out:
# Cloning into 'CosyVoice'...
# remote: Enumerating objects: 1927, done.
# remote: Total 1927 (delta 0), reused 0 (delta 0), pack-reused 1927 (from 1)
# Receiving objects: 100% (1927/1927), 1.57 MiB | 4.16 MiB/s, done.
# Resolving deltas: 100% (1137/1137), done.
# Submodule 'third_party/Matcha-TTS' (https://github.com/shivammehta25/Matcha-TTS.git) registered for path 'third_party/Matcha-TTS'
# Cloning into '/content/CosyVoice/third_party/Matcha-TTS'...
# remote: Enumerating objects: 1078, done.
# remote: Counting objects: 100% (480/480), done.
# remote: Compressing objects: 100% (171/171), done.
# remote: Total 1078 (delta 391), reused 310 (delta 309), pack-reused 598 (from 2)
# Receiving objects: 100% (1078/1078), 64.11 MiB | 24.55 MiB/s, done.
# Resolving deltas: 100% (523/523), done.
# Submodule path 'third_party/Matcha-TTS': checked out 'dd9105b34bf2be2230f4aa1e4769fb586a3c824e'
# /content/CosyVoice
# ...
